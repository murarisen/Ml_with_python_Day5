# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
mydata= pd.read_csv("hotel_bookings.csv")

# %%
mydata.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18156   Resort Hotel            0          1               2015
# 117521    City Hotel            0         39               2017
# 107938    City Hotel            0        170               2017
# 17083   Resort Hotel            0        168               2015
# 84337     City Hotel            0         15               2016
# 28944   Resort Hotel            0        363               2016
# 53326     City Hotel            1        106               2016
# 96255     City Hotel            0         50               2016
# 43749     City Hotel            0         29               2015
# 99354     City Hotel            0        182               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 18156            November                        45
# 117521             August                        31
# 107938              March                        11
# ...

# %%
mydata.shape
# Out:
# (119390, 32)

# %%
mydata.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
mydata.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
mydata.info
# Out:
# <bound method DataFrame.info of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
mydata.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# #### we observe that these are the missing or null values
# #### Agent -float-16340    median/mean
# #### company-float -112593  drop
# #### country -object-488   mode
# #### Children - float- 4  mean/median/mode

# %%
mydata.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
mydata.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
mydata.describe(include="all").T
# Out:
#                                    count unique         top    freq  \
# hotel                             119390      2  City Hotel   79330
# is_canceled                     119390.0    NaN         NaN     NaN
# lead_time                       119390.0    NaN         NaN     NaN
# arrival_date_year               119390.0    NaN         NaN     NaN
# arrival_date_month                119390     12      August   13877
# arrival_date_week_number        119390.0    NaN         NaN     NaN
# arrival_date_day_of_month       119390.0    NaN         NaN     NaN
# stays_in_weekend_nights         119390.0    NaN         NaN     NaN
# stays_in_week_nights            119390.0    NaN         NaN     NaN
# adults                          119390.0    NaN         NaN     NaN
# children                        119386.0    NaN         NaN     NaN
# babies                          119390.0    NaN         NaN     NaN
# meal                              119390      5          BB   92310
# ...

# %%
sns.countplot(x="Product",hue="Gender",data=mydata)### it is use only for categorical
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 sns.countplot(x="Product",hue="Gender",data=mydata)### it is use only for categorical
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
sns.countplot(x="Product",hue="MaritalStatus",data=mydata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sns.countplot(x="Product",hue="MaritalStatus",data=mydata)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
mydata.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'is_canceled'}>,
#         <Axes: title={'center': 'lead_time'}>,
#         <Axes: title={'center': 'arrival_date_year'}>,
#         <Axes: title={'center': 'arrival_date_week_number'}>],
#        [<Axes: title={'center': 'arrival_date_day_of_month'}>,
#         <Axes: title={'center': 'stays_in_weekend_nights'}>,
#         <Axes: title={'center': 'stays_in_week_nights'}>,
#         <Axes: title={'center': 'adults'}>],
#        [<Axes: title={'center': 'children'}>,
#         <Axes: title={'center': 'babies'}>,
#         <Axes: title={'center': 'is_repeated_guest'}>,
#         <Axes: title={'center': 'previous_cancellations'}>],
#        [<Axes: title={'center': 'previous_bookings_not_canceled'}>,
#         <Axes: title={'center': 'booking_changes'}>,
#         <Axes: title={'center': 'agent'}>,
#         <Axes: title={'center': 'company'}>],
#        [<Axes: title={'center': 'days_in_waiting_list'}>,
#         <Axes: title={'center': 'adr'}>,
# ...

# %%
sns.boxplot(x="Product",y="Age",data=mydata)### boxplot one should be numerical
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 sns.boxplot(x="Product",y="Age",data=mydata)### boxplot one should be numerical
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
# ...

# %%
sns.boxplot(x="Age",data=mydata)

# %%
pd.crosstab(mydata["Product"],mydata["Gender"]) ### two categorical table format
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Product'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.pivot_table(mydata,"Income",index=["Product","Gender"],columns=["MaritalStatus"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 pd.pivot_table(mydata,"Income",index=["Product","Gender"],columns=["MaritalStatus"])
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# ...

# %%
sns.pairplot(mydata,diag_kind="kde")

# %%
corr=mydata.corr() #### covariance is tell's about the direction of the reletionship and coreletion is tells about the .... and ...of the reletionship
corr    ### if the value is close to 1 then there is stronge coreletion in +ve and if the value is close to -1 then there is stronge coreletion in -ve and if  the value is 0 then there is no coreletion
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_18824\2349756369.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=mydata.corr() #### covariance is tell's about the direction of the reletionship and coreletion is tells about the .... and ...of the reletionship
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# ...

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
mydata.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 1407    Resort Hotel            0         39               2015
# 21687   Resort Hotel            0          3               2016
# 89546     City Hotel            0         86               2016
# 84150     City Hotel            0         15               2016
# 119109    City Hotel            0        518               2017
# 66461     City Hotel            1        163               2017
# 46456     City Hotel            1        150               2016
# 14180   Resort Hotel            0          2               2015
# 23848   Resort Hotel            0        101               2016
# 62007     City Hotel            1         18               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 1407               August                        35
# 21687               March                        10
# 89546                 May                        21
# ...

# %%
median1=mydata['company'].median()
median1
# Out:
# 179.0

# %%
mydata["company"].replace(np.nan,median1,inplace=True)

# %%
mydata.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
median2=mydata['children'].median()
median2### we can not use median for replace missing values because here median is 0
# Out:
# 0.0

# %%
mean1=mydata['children'].mean()
mean1
# Out:
# 0.10388990333874994

# %%
mydata['children'].replace(np.nan, mean1,inplace=True)

# %%
mydata.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
mode1=mydata['country'].mode()
mode1### we use mode because country is object type
# Out:
# 0    PRT
# Name: country, dtype: object

# %%
mode1
# Out:
# 0    PRT
# Name: country, dtype: object

# %%
mydata['country'].replace(np.nan, mode1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18824\1933511793.py in ?()
# ----> 1 mydata['country'].replace(np.nan, mode1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in ?(self, to_replace, value, inplace, limit, regex, method)
#    5376         limit: int | None = None,
#    5377         regex: bool = False,
#    5378         method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5379     ) -> Series | None:
# ...

# %%
mode1=mydata['country'].mode().values[0]
mode1### we use mode because country is object type
# Out:
# 'PRT'

# %%
mode1
# Out:
# 'PRT'

# %%
mydata['country'].replace(np.nan, mode1,inplace=True)

# %%
mydata.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                               0
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
mydata.drop('agent',axis=1,inplace=True)

# %%
mydata.shape
# Out:
# (119390, 31)

# %%
duplicate=mydata.duplicated()

# %%
duplicate.sum()
# Out:
# 32030

# %%
mydata.boxplot('lead_time')
# Out:
# <Axes: >

# %% [markdown]
# ### Remove Outliers

# %%
def remove_outlier(col):
    sorted(col)
    q1,q3=col.quantile([0.25,0.75])
    iqr=q3-q1
    lower_range=q1-(1.5*iqr)
    upper_range=q3+(1.5*iqr)
    return lower_range,upper_range

# %%
lowleadtime,uppleadtime=remove_outlier(mydata['lead_time'])
mydata['lead_time']=np.where(mydata['lead_time']>uppleadtime,uppleadtime,mydata['lead_time'])
mydata['lead_time']=np.where(mydata['lead_time']<lowleadtime,lowleadtime,mydata['lead_time'])

# %%
mydata.boxplot('lead_time')
# Out:
# <Axes: >
